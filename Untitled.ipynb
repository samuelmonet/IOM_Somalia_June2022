# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pickle
from fonctions import *
#import variables
# Out:
# 2022-06-15 12:05:40.730 INFO    numexpr.utils: NumExpr defaulting to 4 threads.

# %%
questions=pd.read_csv('questions.csv',index_col=0)
questions.drop([i for i in questions if 'Unnamed' in i],axis=1,inplace=True)

# %%
questions
# Out:
#               parent type Treatment  Other  \
# district         NaN  NaN     dummy    NaN
# subdistrict      NaN  NaN     dummy    NaN
# school           NaN  NaN     dummy    NaN
# village          NaN  NaN     dummy    NaN
# gps              NaN  NaN       NaN    NaN
# ...              ...  ...       ...    ...
# shelt DC         NaN  NaN       NaN    NaN
# shelt Elders     NaN  NaN       NaN    NaN
# shelt UN         NaN  NaN       NaN    NaN
# shelt NGO        NaN  NaN       NaN    NaN
# shelt Others     NaN  NaN       NaN    NaN
#
#                                                        question
# district                                       Select District:
# subdistrict                                Select Sub-District:
# school                          Select Primary School of focus:
# village                                          Enter village:
# gps                                                         GPS
# ...                                                         ...
# shelt DC         Most trusted governance system for Shelter: DC
# shelt Elders  Most trusted governance system for Shelter: El...
# shelt UN         Most trusted governance system for Shelter: UN
# shelt NGO       Most trusted governance system for Shelter: NGO
# shelt Others  Most trusted governance system for Shelter: Ot...
#
# [292 rows x 5 columns]
